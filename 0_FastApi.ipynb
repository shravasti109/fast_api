# %% [markdown]
# ###what is api
# >example
# - zopmto show where the delivery man is through he map
# - zomato dont have its own satellite
# - it use google map to show where the delivery man is
# - google give the complete acces ?
# - no
# - only few information google maps show (only requied information)
# - to propected there infromation some app like google provide ap keys

# %% [markdown]
# #campus X

# %% [markdown]
# ###what is api
# - all mechnium which connect tow component
# - Frontend - Udemy suppose user search--> ai agent cours
# - api key request backend to search for --> ai agent course
# - backend search for ai agent course
# - and reponsd to api --> api then return it to frontend

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - customer --> user frontend
# - waiter --> api
# - kitch cook --> backend

# %% [markdown]
# ###why do api exist
# -*need to api*
# - application we want to see ki for two station ke beech mein how many train run
# ###without api how to build the app
# - u give backend two date and two station it will tell no, of train that will pass by
# - how will user intereact (frontend)
# - front will ask backend , backend will ask dataset
# - we have not use api how is front and back are communicatating ?
# - the front and back are so tightly connceted, when ther are developed in one folder it is called **monolitc architecture**  in these type of architeture one folder/ part problem other folder problem too

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### what was problem with monolic archteture
# - the problem was the front and back were tightly connected and if we want to give the database to any other company it was problem beacuse we can not give the direct access
# - because what if they delete the data and also some data is private

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - when api reply i give the response in json format json is dictionary,every langugae can undersatnd json
# - when ths smart phone got really popular company statr to make app
# - to dofferent app there was anroid app and then there was apple app
# - to make these android app and apple app we write the code in different language
# - if i commented the comment should be apperning in apple as well as android so api help
# -there type of front pple and andriod and web
# - no monolith architeture

# %% [markdown]
# ##what is fast api
# - fast api is python framework which is made up of sharlette and pydantic
# - starlette is recevice the request in htts and repsonce to it in https
# - pydantic as it is having very strict format  if datatype is integre then integer is only allowed

# %% [markdown]
# ## Philosophy of Fast api
# - fast to run
# - fast to code

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - web server and api code both are programmed in diferent language
# - sgi act as a translator
